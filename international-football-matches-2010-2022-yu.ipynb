# %% [markdown]
# # Installing neccessary packages

# %%
library(tidyverse)
library(lubridate)

# %% [markdown]
# # Import csv file "International football results from 1872 to 2022"

# %%
results <- read.csv2("https://raw.githubusercontent.com/martj42/international_results/master/results.csv", header = TRUE, sep = ",")
results

# %% [markdown]
# # Select results since 2010

# %%
results %>%
    filter(date >=2010) %>%
    select(-country, -city) -> results
results

# %% [markdown]
# # Select results from 32 participants

# %%
#select results from canada
results %>%
  filter(home_team == "Canada") -> result_canada_home

results %>%
  filter(away_team == "Canada") -> result_canada_away

bind_rows(result_canada_home, result_canada_away) -> result_canada

result_canada %>%
  arrange(date) %>%
  mutate(country = "Canada") -> result_canada

#select results from Wales
results %>%
  filter(home_team == "Wales") -> result_wales_home

results %>%
  filter(away_team == "Wales") -> result_wales_away

bind_rows(result_wales_home, result_wales_away) -> result_wales

result_wales %>%
  arrange(date) %>%
  mutate(country = "Wales") -> result_wales

#select results from Qatar
results %>%
  filter(home_team == "Qatar") -> result_qatar_home

results %>%
  filter(away_team == "Qatar") -> result_qatar_away

bind_rows(result_qatar_home, result_qatar_away) -> result_qatar

result_qatar %>%
  arrange(date) %>%
  mutate(country = "Qatar") -> result_qatar

#select results from Ecuador
results %>%
  filter(home_team == "Ecuador") -> result_ecuador_home

results %>%
  filter(away_team == "Ecuador") -> result_ecuador_away

bind_rows(result_ecuador_home, result_ecuador_away) -> result_ecuador

result_ecuador %>%
  arrange(date) %>%
  mutate(country = "Ecuador") -> result_ecuador

#select results from Senegal
results %>%
  filter(home_team == "Senegal") -> result_senegal_home

results %>%
  filter(away_team == "Senegal") -> result_senegal_away

bind_rows(result_senegal_home, result_senegal_away) -> result_senegal

result_senegal %>%
  arrange(date) %>%
  mutate(country = "Senegal") -> result_senegal

#select results from Netherlands
results %>%
  filter(home_team == "Netherlands") -> result_netherlands_home

results %>%
  filter(away_team == "Netherlands") -> result_netherlands_away

bind_rows(result_netherlands_home, result_netherlands_away) -> result_netherlands

result_netherlands %>%
  arrange(date) %>%
  mutate(country = "Netherlands") -> result_netherlands

#select results from England
results %>%
  filter(home_team == "England") -> result_england_home

results %>%
  filter(away_team == "England") -> result_england_away

bind_rows(result_england_home, result_england_away) -> result_england

result_england %>%
  arrange(date) %>%
  mutate(country = "England") -> result_england

#select results from Iran
results %>%
  filter(home_team == "Iran") -> result_iran_home

results %>%
  filter(away_team == "Iran") -> result_iran_away

bind_rows(result_iran_home, result_iran_away) -> result_iran

result_iran %>%
  arrange(date) %>%
  mutate(country = "Iran") -> result_iran

#select results from United States
results %>%
  filter(home_team == "United States") -> result_unitedstates_home

results %>%
  filter(away_team == "United States") -> result_unitedstates_away

bind_rows(result_unitedstates_home, result_unitedstates_away) -> result_unitedstates

result_unitedstates %>%
  arrange(date) %>%
  mutate(country = "United States") -> result_unitedstates

#select results from Argentina
results %>%
  filter(home_team == "Argentina") -> result_argentina_home

results %>%
  filter(away_team == "Argentina") -> result_argentina_away

bind_rows(result_argentina_home, result_argentina_away) -> result_argentina

result_argentina %>%
  arrange(date) %>%
  mutate(country = "Argentina") -> result_argentina

#select results from Saudi Arabia
results %>%
  filter(home_team == "Saudi Arabia") -> result_saudiarabia_home

results %>%
  filter(away_team == "Saudi Arabia") -> result_saudiarabia_away

bind_rows(result_saudiarabia_home, result_saudiarabia_away) -> result_saudiarabia

result_saudiarabia %>%
  arrange(date) %>%
  mutate(country = "Saudi Arabia") -> result_saudiarabia

#select results from Mexico
results %>%
  filter(home_team == "Mexico") -> result_mexico_home

results %>%
  filter(away_team == "Mexico") -> result_mexico_away

bind_rows(result_mexico_home, result_mexico_away) -> result_mexico

result_mexico %>%
  arrange(date) %>%
  mutate(country = "Mexico") -> result_mexico

#select results from Poland
results %>%
  filter(home_team == "Poland") -> result_poland_home

results %>%
  filter(away_team == "Poland") -> result_poland_away

bind_rows(result_poland_home, result_poland_away) -> result_poland

result_poland %>%
  arrange(date) %>%
  mutate(country = "Poland") -> result_poland

#select results from France
results %>%
  filter(home_team == "France") -> result_france_home

results %>%
  filter(away_team == "France") -> result_france_away

bind_rows(result_france_home, result_france_away) -> result_france

result_france %>%
  arrange(date) %>%
  mutate(country = "France") -> result_france

#select results from Australia
results %>%
  filter(home_team == "Australia") -> result_australia_home

results %>%
  filter(away_team == "Australia") -> result_australia_away

bind_rows(result_australia_home, result_australia_away) -> result_australia

result_australia %>%
  arrange(date) %>%
  mutate(country = "Australia") -> result_australia

#select results from Denmark
results %>%
  filter(home_team == "Denmark") -> result_denmark_home

results %>%
  filter(away_team == "Denmark") -> result_denmark_away

bind_rows(result_denmark_home, result_denmark_away) -> result_denmark

result_denmark %>%
  arrange(date) %>%
  mutate(country = "Denmark") -> result_denmark

#select results from Tunisia
results %>%
  filter(home_team == "Tunisia") -> result_tunisia_home

results %>%
  filter(away_team == "Tunisia") -> result_tunisia_away

bind_rows(result_tunisia_home, result_tunisia_away) -> result_tunisia

result_tunisia %>%
  arrange(date) %>%
  mutate(country = "Tunisia") -> result_tunisia

#select results from Spain
results %>%
  filter(home_team == "Spain") -> result_spain_home

results %>%
  filter(away_team == "Spain") -> result_spain_away

bind_rows(result_spain_home, result_spain_away) -> result_spain

result_spain %>%
  arrange(date) %>%
  mutate(country = "Spain") -> result_spain

#select results from Costa Rica
results %>%
  filter(home_team == "Costa Rica") -> result_costarica_home

results %>%
  filter(away_team == "Costa Rica") -> result_costarica_away

bind_rows(result_costarica_home, result_costarica_away) -> result_costarica

result_costarica %>%
  arrange(date) %>%
  mutate(country = "Costa Rica") -> result_costarica

#select results from Germany
results %>%
  filter(home_team == "Germany") -> result_germany_home

results %>%
  filter(away_team == "Germany") -> result_germany_away

bind_rows(result_germany_home, result_germany_away) -> result_germany

result_germany %>%
  arrange(date) %>%
  mutate(country = "Germany") -> result_germany

#select results from Japan
results %>%
  filter(home_team == "Japan") -> result_japan_home

results %>%
  filter(away_team == "Japan") -> result_japan_away

bind_rows(result_japan_home, result_japan_away) -> result_japan

result_japan %>%
  arrange(date) %>%
  mutate(country = "Japan") -> result_japan

#select results from Belgium
results %>%
  filter(home_team == "Belgium") -> result_belgium_home

results %>%
  filter(away_team == "Belgium") -> result_belgium_away

bind_rows(result_belgium_home, result_belgium_away) -> result_belgium

result_belgium %>%
  arrange(date) %>%
  mutate(country = "Belgium") -> result_belgium

#select results from Morocco
results %>%
  filter(home_team == "Morocco") -> result_morocco_home

results %>%
  filter(away_team == "Morocco") -> result_morocco_away

bind_rows(result_morocco_home, result_morocco_away) -> result_morocco

result_morocco %>%
  arrange(date) %>%
  mutate(country = "Morocco") -> result_morocco

#select results from Croatia
results %>%
  filter(home_team == "Croatia") -> result_croatia_home

results %>%
  filter(away_team == "Croatia") -> result_croatia_away

bind_rows(result_croatia_home, result_croatia_away) -> result_croatia

result_croatia %>%
  arrange(date) %>%
  mutate(country = "Croatia") -> result_croatia

#select results from Brazil
results %>%
  filter(home_team == "Brazil") -> result_brazil_home

results %>%
  filter(away_team == "Brazil") -> result_brazil_away

bind_rows(result_brazil_home, result_brazil_away) -> result_brazil

result_brazil %>%
  arrange(date) %>%
  mutate(country = "Brazil") -> result_brazil

#select results from Serbia
results %>%
  filter(home_team == "Serbia") -> result_serbia_home

results %>%
  filter(away_team == "Serbia") -> result_serbia_away

bind_rows(result_serbia_home, result_serbia_away) -> result_serbia

result_serbia %>%
  arrange(date) %>%
  mutate(country = "Serbia") -> result_serbia

#select results from Switzerland
results %>%
  filter(home_team == "Switzerland") -> result_switzerland_home

results %>%
  filter(away_team == "Switzerland") -> result_switzerland_away

bind_rows(result_switzerland_home, result_switzerland_away) -> result_switzerland

result_switzerland %>%
  arrange(date) %>%
  mutate(country = "Switzerland") -> result_switzerland

#select results from Cameroon
results %>%
  filter(home_team == "Cameroon") -> result_cameroon_home

results %>%
  filter(away_team == "Cameroon") -> result_cameroon_away

bind_rows(result_cameroon_home, result_cameroon_away) -> result_cameroon

result_cameroon %>%
  arrange(date) %>%
  mutate(country = "Cameroon") -> result_cameroon

#select results from Portugal
results %>%
  filter(home_team == "Portugal") -> result_portugal_home

results %>%
  filter(away_team == "Portugal") -> result_portugal_away

bind_rows(result_portugal_home, result_portugal_away) -> result_portugal

result_portugal %>%
  arrange(date) %>%
  mutate(country = "Portugal") -> result_portugal

#select results from Ghana
results %>%
  filter(home_team == "Ghana") -> result_ghana_home

results %>%
  filter(away_team == "Ghana") -> result_ghana_away

bind_rows(result_ghana_home, result_ghana_away) -> result_ghana

result_ghana %>%
  arrange(date) %>%
  mutate(country = "Ghana") -> result_ghana

#select results from Uruguay
results %>%
  filter(home_team == "Uruguay") -> result_uruguay_home

results %>%
  filter(away_team == "Uruguay") -> result_uruguay_away

bind_rows(result_uruguay_home, result_uruguay_away) -> result_uruguay

result_uruguay %>%
  arrange(date) %>%
  mutate(country = "Uruguay") -> result_uruguay

#select results from South Korea
results %>%
  filter(home_team == "South Korea") -> result_southkorea_home

results %>%
  filter(away_team == "South Korea") -> result_southkorea_away

bind_rows(result_southkorea_home, result_southkorea_away) -> result_southkorea

result_southkorea %>%
  arrange(date) %>%
  mutate(country = "South Korea") -> result_southkorea

# %% [markdown]
# # Combine all dataframes into one

# %%
# combine all dataframes into one dataframe, delete the repeated rows
results_selected <- bind_rows(result_qatar, result_ecuador, result_senegal, result_netherlands, result_england, result_iran, result_unitedstates, result_wales, result_argentina, result_saudiarabia, result_mexico, result_poland, result_france, result_australia, result_denmark, result_spain, result_costarica, result_germany, result_japan, result_belgium, result_canada, result_morocco, result_croatia, result_brazil, result_serbia, result_switzerland, result_cameroon, result_portugal, result_ghana, result_uruguay, result_southkorea)

results_selected %>%
  arrange(date) -> results_selected

results_selected

# %% [markdown]
# # Continue process dataframe

# %%
#compare scores from home and away teams
  results_selected %>%
    mutate(Status = home_score - away_score) -> result_processed_1

#get finalresults of the games, focused on home teams
  mutate(result_processed_1, 
         HomeFinalStatus = ifelse(Status > 0, "Win", ifelse(Status < 0, "Lose", "Draw"))) -> result_processed_2
  
  mutate(result_processed_2, 
         AwayFinalStatus = ifelse(Status > 0, "Lose", ifelse(Status < 0, "Win", "Draw"))) -> result_processed_2

#confirm if home team is country or not
  mutate(result_processed_2, 
         HomeCountry = ifelse(country == home_team, "TRUE", "FALSE")) -> result_processed_3

#confirm FinalResults accroding to finalstatus and homecountry
  mutate(result_processed_3, 
         FinalResult = ifelse(HomeCountry == "TRUE", HomeFinalStatus, AwayFinalStatus)) -> result_processed_4

#reduce redundant colomns
  result_processed_4 %>%
    select(-Status, -HomeFinalStatus, -AwayFinalStatus, -HomeCountry) -> result_processed_5

result_processed_5
